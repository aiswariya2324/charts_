# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
db = pd.read_csv("/content/drive/MyDrive/Dataset/Car_sales.csv")

# %%
sns.heatmap(db.isnull())
# Out:
# <Axes: >

# %%
db.shape
# Out:
# (157, 16)

# %%
db.drop_duplicates()
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
db.shape
# Out:
# (157, 16)

# %%
db.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
db1 = db["__year_resale_value"].fillna(value = mean, inplace = True)

# %%
dbb=db.drop(["Manufacturer","Model","Vehicle_type"],axis=1)

# %%
db.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Dataset/Car_sales.csv")

# %%
dataset.Engine_size.isnull().sum()
# Out:
# 1

# %%
dataset.Engine_size.fillna(dataset["Engine_size"].mean(), inplace = True)

# %%
eng =dataset['Engine_size']

# %%
print(plt.hist(eng, bins = 3))
# Out:
# (array([103.,  51.,   3.]), array([1.        , 3.33333333, 5.66666667, 8.        ]), <BarContainer object of 3 artists>)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
db[cols_to_scale] = scaler.fit_transform(db[cols_to_scale])

# %%
db[cols_to_scale].head()
# Out:
#    Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0            0.031102             0.179516            0.160821     0.114286
# 1            0.072669             0.235855            0.251295     0.314286
# 2            0.025912             0.209409            0.238061     0.314286
# 3            0.015687             0.393733            0.429620     0.357143
# 4            0.037537             0.274002            0.193470     0.114286
#
#    Wheelbase     Width    Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# 0   0.186551  0.271676  0.306258     0.202339       0.133641         0.433333
# 1   0.336226  0.445087  0.579228     0.441120       0.317972         0.333333
# 2   0.310195  0.462428  0.567244     0.428338       0.317972         0.366667
# 3   0.477223  0.508671  0.628495     0.531683       0.354839         0.233333
# 4   0.216920  0.323699  0.380826     0.299973       0.281106         0.400000
#
#    Power_perf_factor
# ...
